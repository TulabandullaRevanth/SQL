# %%
import pymongo
import pandas as pd

# %% [markdown]
# 1.Write a Python program to connect to MySQL and print the list of all available databases.

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client['fastapi_db']
from pymongo import MongoClient
print("Database created........")
print("List of databases after creating new one")
print(client.list_database_names())
# Out:
# Database created........
# List of databases after creating new one
# ['admin', 'config', 'local', 'schools_db']

# %% [markdown]
# 2.Create a function in Python to create the tables (students, courses, enrollments) in school_db.
# 3.Write a Python program to insert multiple students and courses into the respective tables using executemany().

# %%
students = db["students"]
studentsp=pd.read_csv("./students.csv")
df_students = studentsp.to_dict(orient="records")
db.students.insert_many(df_students)
print("CSV data uploaded successfully!")
# Out:
# CSV data uploaded successfully!

# %%
courses = db["courses"]
coursesp=pd.read_csv("./courses.csv")
df_courses = coursesp.to_dict(orient="records")
db.courses.insert_many(df_courses)
print("CSV data uploaded successfully!")
# Out:
# CSV data uploaded successfully!

# %% [markdown]
# 4. Fetch and print all rows from the students table in a tabular format.

# %%
cursor = db.students.find()
for srows in cursor:
    print(srows)
# Out:
# {'_id': ObjectId('68dbbb46141a137e54bf5757'), 'student_id': 1, 'name': 'Zane1', 'age': 18, 'grade': 'C', 'email': 'zane1816@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf5758'), 'student_id': 2, 'name': 'Uma2', 'age': 23, 'grade': 'A', 'email': 'uma2583@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf5759'), 'student_id': 3, 'name': 'Wendy3', 'age': 22, 'grade': 'B', 'email': 'wendy3551@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf575a'), 'student_id': 4, 'name': 'Xander4', 'age': 22, 'grade': 'A', 'email': 'xander4736@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf575b'), 'student_id': 5, 'name': 'Victor5', 'age': 19, 'grade': 'A', 'email': 'victor5226@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf575c'), 'student_id': 6, 'name': 'Ian6', 'age': 19, 'grade': 'D', 'email': 'ian6392@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf575d'), 'student_id': 7, 'name': 'Leo7', 'age': 22, 'grade': 'A', 'email': 'leo7439@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf575e'), 'student_id': 8, 'name': 'Paul8', 'age': 24, 'grade': 'B', 'email': 'paul8435@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf575f'), 'student_id': 9, 'name': 'Wendy9', 'age': 23, 'grade': 'B', 'email': 'wendy9240@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf5760'), 'student_id': 10, 'name': 'Leo10', 'age': 23, 'grade': 'A', 'email': 'leo10980@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5761'), 'student_id': 11, 'name': 'Uma11', 'age': 18, 'grade': 'C', 'email': 'uma11314@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5762'), 'student_id': 12, 'name': 'Rita12', 'age': 18, 'grade': 'B', 'email': 'rita12440@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5763'), 'student_id': 13, 'name': 'Yara13', 'age': 22, 'grade': 'B', 'email': 'yara13854@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5764'), 'student_id': 14, 'name': 'Bob14', 'age': 19, 'grade': 'C', 'email': 'bob14854@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5765'), 'student_id': 15, 'name': 'Quincy15', 'age': 24, 'grade': 'A', 'email': 'quincy15400@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf5766'), 'student_id': 16, 'name': 'Tina16', 'age': 19, 'grade': 'A', 'email': 'tina16274@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf5767'), 'student_id': 17, 'name': 'Alice17', 'age': 25, 'grade': 'B', 'email': 'alice17904@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf5768'), 'student_id': 18, 'name': 'Sam18', 'age': 20, 'grade': 'B', 'email': 'sam18920@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf
school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a4'), 'student_id': 78, 'name': 'Ian78', 'age': 22, 'grade': 'D', 'email': 'ian78228@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a5'), 'student_id': 79, 'name': 'Xander79', 'age': 24, 'grade': 'C', 'email': 'xander79935@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a6'), 'student_id': 80, 'name': 'Tina80', 'age': 22, 'grade': 'D', 'email': 'tina80300@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a7'), 'student_id': 81, 'name': 'Wendy81', 'age': 20, 'grade': 'A', 'email': 'wendy81147@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a8'), 'student_id': 82, 'name': 'Karen82', 'age': 23, 'grade': 'B', 'email': 'karen82995@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57a9'), 'student_id': 83, 'name': 'Leo83', 'age': 18, 'grade': 'C', 'email': 'leo83394@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57aa'), 'student_id': 84, 'name': 'Bob84', 'age': 18, 'grade': 'A', 'email': 'bob84871@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57ab'), 'student_id': 85, 'name': 'Rita85', 'age': 18, 'grade': 'A', 'email': 'rita85757@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57ac'), 'student_id': 86, 'name': 'Alice86', 'age': 21, 'grade': 'B', 'email': 'alice86674@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57ad'), 'student_id': 87, 'name': 'Sam87', 'age': 19, 'grade': 'C', 'email': 'sam87600@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57ae'), 'student_id': 88, 'name': 'Wendy88', 'age': 23, 'grade': 'A', 'email': 'wendy88626@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57af'), 'student_id': 89, 'name': 'Tina89', 'age': 21, 'grade': 'C', 'email': 'tina89877@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b0'), 'student_id': 90, 'name': 'Zane90', 'age': 25, 'grade': 'D', 'email': 'zane90905@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b1'), 'student_id': 91, 'name': 'Tina91', 'age': 21, 'grade': 'D', 'email': 'tina91565@school.edu'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b2'), 'student_id': 92, 'name': 'Wendy92', 'age': 19, 'grade': 'C', 'email': 'wendy92509@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b3'), 'student_id': 93, 'name': 'Quincy93', 'age': 19, 'grade': 'A', 'email': 'quincy93754@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b4'), 'student_id': 94, 'name': 'Eva94', 'age': 24, 'grade': 'C', 'email': 'eva94917@outlook.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b5'), 'student_id': 95, 'name': 'Tina95', 'age': 25, 'grade': 'D', 'email': 'tina95115@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b6'), 'student_id': 96, 'name': 'Ian96', 'age': 25, 'grade': 'C', 'email': 'ian96659@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b7'), 'student_id': 97, 'name': 'Mona97', 'age': 22, 'grade': 'C', 'email': 'mona97589@yahoo.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b8'), 'student_id': 98, 'name': 'Leo98', 'age': 25, 'grade': 'A', 'email': 'leo98916@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57b9'), 'student_id': 99, 'name': 'Bob99', 'age': 23, 'grade': 'C', 'email': 'bob99616@gmail.com'}
# {'_id': ObjectId('68dbbb46141a137e54bf57ba'), 'student_id': 100, 'name': 'Paul100', 'age': 19, 'grade': 'B', 'email': 'paul100458@outlook.com'}

# %% [markdown]
# 5 .Write a program to update the grade of a student (given student_id) via a Python input prompt.

# %%
db.students.update_one({"student_id": 1},{"$set": {"age": 21}})
print(db.students.find_one({"student_id": 1}))
# Out:
# {'_id': ObjectId('68dbbb46141a137e54bf5757'), 'student_id': 1, 'name': 'Zane1', 'age': 21, 'grade': 'C', 'email': 'zane1816@outlook.com'}

# %% [markdown]
# 6 .Delete a student from the students table using Python input for student_id.

# %%
db.students.delete_one({"name" : "Uma2"})
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %% [markdown]
# 7 .Write a Python script to insert enrollment records linking students with their courses, ensuring foreign key integrity.

# %%
student_id = int(input("Enter Student ID: "))
course_id = int(input("Enter Course ID: "))

student = db.students.find_one({"student_id": student_id})
course = db.students.find_one({"course_id": course_id})


if student and course:
    db.enrollment.insert_one({
        "student_id": student_id,
        "course_id": course_id
    })
    print("Enrollment added successfully!")
else:
    print("Error: Student or Course does not exist (foreign key check failed).")
# Out:
# Error: Student or Course does not exist (foreign key check failed).

# %% [markdown]
# 8 .Fetch all students enrolled in a particular course (given course_id as input).

# %%
course_id = int(input("Enter course ID: "))

# Step 1: Find all enrollments for the course
enrollments = db.enrollment.find({"course_id": course_id}, {"student_id": 1, "_id": 0})

# Step 2: Fetch matching students
student_ids = [e["student_id"] for e in enrollments]

if student_ids:
    students = db.students.find({"student_id": {"$in": student_ids}}, {"_id": 0})
    print("\nStudents enrolled in course", course_id)
    for s in students:
        print(s)
else:
    print("No students enrolled in this course.")
# Out:
# No students enrolled in this course.

# %% [markdown]
# 9 .Write a program to display students who are not enrolled in any course.

# %%
pipeline = [
    {"$lookup": {
        "from": "enrollment",          
        "localField": "student_id",   
        "foreignField": "student_id",
        "as": "enrolled"
    }},
    {"$match": {"enrolled": {"$eq": []}}},
    {"$project": {"_id": 0, "student_id": 1, "name": 1}}
]

results = list(db.students.aggregate(pipeline))
if results:
    for r in results:
        print(r)
else:
    print("All students are enrolled in at least one course.")
# Out:
# {'student_id': 1, 'name': 'Zane1'}
# {'student_id': 3, 'name': 'Wendy3'}
# {'student_id': 4, 'name': 'Xander4'}
# {'student_id': 5, 'name': 'Victor5'}
# {'student_id': 6, 'name': 'Ian6'}
# {'student_id': 7, 'name': 'Leo7'}
# {'student_id': 8, 'name': 'Paul8'}
# {'student_id': 9, 'name': 'Wendy9'}
# {'student_id': 10, 'name': 'Leo10'}
# {'student_id': 11, 'name': 'Uma11'}
# {'student_id': 12, 'name': 'Rita12'}
# {'student_id': 13, 'name': 'Yara13'}
# {'student_id': 14, 'name': 'Bob14'}
# {'student_id': 15, 'name': 'Quincy15'}
# {'student_id': 16, 'name': 'Tina16'}
# {'student_id': 17, 'name': 'Alice17'}
# {'student_id': 18, 'name': 'Sam18'}
# {'student_id': 19, 'name': 'Paul19'}
# {'student_id': 20, 'name': 'Victor20'}
# {'student_id': 21, 'name': 'Frank21'}
# {'student_id': 22, 'name': 'Victor22'}
# {'student_id': 23, 'name': 'Karen23'}
# {'student_id': 24, 'name': 'Grace24'}
# {'student_id': 25, 'name': 'Quincy25'}
# {'student_id': 26, 'name': 'Mona26'}
# {'student_id': 27, 'name': 'Uma27'}
# {'student_id': 28, 'name': 'Nina28'}
# {'student_id': 29, 'name': 'Ian29'}
# {'student_id': 30, 'name': 'Tina30'}
# {'student_id': 31, 'name': 'Nina31'}
# {'student_id': 32, 'name': 'Hannah32'}
# {'student_id': 33, 'name': 'David33'}
# {'student_id': 34, 'name': 'Wendy34'}
# {'student_id': 35, 'name': 'Frank35'}
# {'student_id': 36, 'name': 'Paul36'}
# {'student_id': 37, 'name': 'Ian37'}
# {'student_id': 38, 'name': 'Paul38'}
# {'student_id': 39, 'name': 'Hannah39'}
# {'student_id': 40, 'name': 'Zane40'}
# {'student_id': 41, 'name': 'Ian41'}
# {'student_id': 42, 'name': 'Quincy42'}
# {'student_id': 43, 'name': 'Quincy43'}
# {'student_id': 44, 'name': 'Tina44'}
# {'student_id': 45, 'name': 'Xander45'}
# {'student_id': 46, 'name': 'Zane46'}
# {'student_id': 47, 'name': 'Eva47'}
# {'student_id': 48, 'name': 'Leo48'}
# {'student_id': 49, 'name': 'Uma49'}
# {'student_id': 50, 'name': 'Bob50'}
# {'student_id': 51, 'name': 'Karen51'}
# {'student_id': 52, 'name': 'Hannah52'}
# {'student_id': 53, 'name': 'Bob53'}
# {'student_id': 54, 'name': 'Leo54'}
# {'student_id': 55, 'name': 'Yara55'}
# {'student_id': 56, 'name': 'Eva56'}
# {'student_id': 57, 'name': 'Nina57'}
# {'student_id': 58, 'name': 'Eva58'}
# {'student_id': 59, 'name': 'Oscar59'}
# {'student_id': 60, 'name': 'Yara60'}
# {'student_id': 61, 'name': 'Oscar61'}
# {'student_id': 62, 'name': 'Rita62'}
# {'student_id': 63, 'name': 'Victor63'}
# {'student_id': 64, 'name': 'Xander64'}
# {'student_id': 65, 'name': 'Hannah65'}
# {'student_id': 66, 'name': 'Nina66'}
# {'student_id': 67, 'name': 'Victor67'}
# {'student_id': 68, 'name': 'Karen68'}
# {'student_id': 69, 'name': 'Grace69'}
# {'student_id': 70, 'name': 'Jack70'}
# {'student_id': 71, 'name': 'Nina71'}
# {'student_id': 72, 'name': 'Ian72'}
# {'student_id': 73, 'name': 'Grace73'}
# {'student_id': 74, 'name': 'Grace74'}
# {'student_id': 75, 'name': 'Quincy75'}
# {'student_id': 76, 'name': 'Oscar76'}
# {'student_id': 77, 'name': 'Grace77'}
# {'student_id': 78, 'name': 'Ian78'}
# {'student_id': 79, 'name': 'Xander79'}
# {'student_id': 80, 'name': 'Tina80'}
# {'student_id': 81, 'name': 'Wendy81'}
# {'student_id': 82, 'name': 'Karen82'}
# {'student_id': 83, 'name': 'Leo83'}
# {'student_id': 84, 'name': 'Bob84'}
# {'student_id': 85, 'name': 'Rita85'}
# {'student_id': 86, 'name': 'Alice86'}
# {'student_id': 87, 'name': 'Sam87'}
# {'student_id': 88, 'name': 'Wendy88'}
# {'student_id': 89, 'name': 'Tina89'}
# {'student_id': 90, 'name': 'Zane90'}
# {'student_id': 91, 'name': 'Tina91'}
# {'student_id': 92, 'name': 'Wendy92'}
# {'student_id': 93, 'name': 'Quincy93'}
# {'student_id': 94, 'name': 'Eva94'}
# {'student_id': 95, 'name': 'Tina95'}
# {'student_id': 96, 'name': 'Ian96'}
# {'student_id': 97, 'name': 'Mona97'}
# {'student_id': 98, 'name': 'Leo98'}
# {'student_id': 99, 'name': 'Bob99'}
# {'student_id': 100, 'name': 'Paul100'}

# %% [markdown]
# 10 .Perform an INNER JOIN between students and courses using Python to show student names along with the courses they are enrolled in.

# %%
pipeline = [
    {"$lookup": {
        "from": "students",
        "localField": "student_id",
        "foreignField": "student_id",
        "as": "student_info"
    }},
    {"$unwind": "$student_info"},
    
    {"$lookup": {
        "from": "courses",
        "localField": "course_id",
        "foreignField": "course_id",
        "as": "course_info"
    }},
    {"$unwind": "$course_info"},
    
    {"$project": {
        "_id": 0,
        "student_name": "$student_info.name",
        "course_name": "$course_info.course_name"
    }}
]

results = list(db.enrollment.aggregate(pipeline))
for r in results:
    print(f"{r['student_name']} → {r['course_name']}")

# %% [markdown]
# 11 .Write a Python function to search for a student by name (partial matches allowed using LIKE).

# %%
results = list(db.students.find(student, {"_id": 0, "student_id": 1, "name": 1, "grade": 1}))
if results:
    for r in results:
            print(f"ID: {r['student_id']} | Name: {r['name']} | Grade: {r['grade']}")
else:
        print(f"No students found matching .")
# Out:
# ID: 1 | Name: Zane1 | Grade: C

# %% [markdown]
# 12 .Add a new column email to the students table using Python and update it with random values.

# %%
import numpy as np

domains = ["gmail.com", "yahoo.com", "outlook.com", "example.com"]
chars = list("abcdefghijklmnopqrstuvwxyz0123456789")

for s in db.students.find({}, {"_id": 0, "student_id": 1, "name": 1}):
    random_str = ''.join(np.random.choice(chars, 3))
    domain = np.random.choice(domains)
    school_email = f"{s['name'].lower()}{random_str}@{domain}"

    db.students.update_one(
        {"student_id": s["student_id"]},
        {"$set": {"school_email": school_email}}
    )

print("Emails added successfully!")

for s in db.students.find({}, {"_id": 0, "student_id": 1, "name": 1, "email": 1}):
    print(s)
# Out:
# Emails added successfully!
# {'student_id': 1, 'name': 'Zane1', 'email': 'zane1816@outlook.com'}
# {'student_id': 3, 'name': 'Wendy3', 'email': 'wendy3551@outlook.com'}
# {'student_id': 4, 'name': 'Xander4', 'email': 'xander4736@yahoo.com'}
# {'student_id': 5, 'name': 'Victor5', 'email': 'victor5226@yahoo.com'}
# {'student_id': 6, 'name': 'Ian6', 'email': 'ian6392@school.edu'}
# {'student_id': 7, 'name': 'Leo7', 'email': 'leo7439@outlook.com'}
# {'student_id': 8, 'name': 'Paul8', 'email': 'paul8435@yahoo.com'}
# {'student_id': 9, 'name': 'Wendy9', 'email': 'wendy9240@yahoo.com'}
# {'student_id': 10, 'name': 'Leo10', 'email': 'leo10980@school.edu'}
# {'student_id': 11, 'name': 'Uma11', 'email': 'uma11314@school.edu'}
# {'student_id': 12, 'name': 'Rita12', 'email': 'rita12440@school.edu'}
# {'student_id': 13, 'name': 'Yara13', 'email': 'yara13854@school.edu'}
# {'student_id': 14, 'name': 'Bob14', 'email': 'bob14854@school.edu'}
# {'student_id': 15, 'name': 'Quincy15', 'email': 'quincy15400@outlook.com'}
# {'student_id': 16, 'name': 'Tina16', 'email': 'tina16274@gmail.com'}
# {'student_id': 17, 'name': 'Alice17', 'email': 'alice17904@school.edu'}
# {'student_id': 18, 'name': 'Sam18', 'email': 'sam18920@gmail.com'}
# {'student_id': 19, 'name': 'Paul19', 'email': 'paul19130@yahoo.com'}
# {'student_id': 20, 'name': 'Victor20', 'email': 'victor20945@school.edu'}
# {'student_id': 21, 'name': 'Frank21', 'email': 'frank21655@school.edu'}
# {'student_id': 22, 'name': 'Victor22', 'email': 'victor22513@school.edu'}
# {'student_id': 23, 'name': 'Karen23', 'email': 'karen23159@gmail.com'}
# {'student_id': 24, 'name': 'Grace24', 'email': 'grace24405@outlook.com'}
# {'student_id': 25, 'name': 'Quincy25', 'email': 'quincy25691@school.edu'}
# {'student_id': 26, 'name': 'Mona26', 'email': 'mona26828@yahoo.com'}
# {'student_id': 27, 'name': 'Uma27', 'email': 'uma27872@outlook.com'}
# {'student_id': 28, 'name': 'Nina28', 'email': 'nina28574@yahoo.com'}
# {'student_id': 29, 'name': 'Ian29', 'email': 'ian29171@yahoo.com'}
# {'student_id': 30, 'name': 'Tina30', 'email': 'tina30967@outlook.com'}
# {'student_id': 31, 'name': 'Nina31', 'email': 'nina31454@gmail.com'}
# {'student_id': 32, 'name': 'Hannah32', 'email': 'hannah32814@outlook.com'}
# {'student_id': 33, 'name': 'David33', 'email': 'david33904@outlook.com'}
# {'student_id': 34, 'name': 'Wendy34', 'email': 'wendy34558@yahoo.com'}
# {'student_id': 35, 'name': 'Frank35', 'email': 'frank35378@yahoo.com'}
# {'student_id': 36, 'name': 'Paul36', 'email': 'paul36817@school.edu'}
# {'student_id': 37, 'name': 'Ian37', 'email': 'ian37515@gmail.com'}
# {'student_id': 38, 'name': 'Paul38', 'email': 'paul38348@yahoo.com'}
# {'student_id': 39, 'name': 'Hannah39', 'email': 'hannah39791@outlook.com'}
# {'student_id': 40, 'name': 'Zane40', 'email': 'zane40746@gmail.com'}
# {'student_id': 41, 'name': 'Ian41', 'email': 'ian41234@outlook.com'}
# {'student_id': 42, 'name': 'Quincy42', 'email': 'quincy42506@gmail.com'}
# {'student_id': 43, 'name': 'Quincy43', 'email': 'quincy43300@outlook.com'}
# {'student_id': 44, 'name': 'Tina44', 'email': 'tina44702@yahoo.com'}
# {'student_id': 45, 'name': 'Xander45', 'email': 'xander45304@school.edu'}
# {'student_id': 46, 'name': 'Zane46', 'email': 'zane46588@school.edu'}
# {'student_id': 47, 'name': 'Eva47', 'email': 'eva47575@yahoo.com'}
# {'student_id': 48, 'name': 'Leo48', 'email': 'leo48302@gmail.com'}
# {'student_id': 49, 'name': 'Uma49', 'email': 'uma49138@gmail.com'}
# {'student_id': 50, 'name': 'Bob50', 'email': 'bob50476@school.edu'}
# {'student_id': 51, 'name': 'Karen51', 'email': 'karen51868@outlook.com'}
# {'student_id': 52, 'name': 'Hannah52', 'email': 'hannah52672@yahoo.com'}
# {'student_id': 53, 'name': 'Bob53', 'email': 'bob53464@gmail.com'}
# {'student_id': 54, 'name': 'Leo54', 'email': 'leo54376@gmail.com'}
# {'student_id': 55, 'name': 'Yara55', 'email': 'yara55326@outlook.com'}
# {'student_id': 56, 'name': 'Eva56', 'email': 'eva56617@school.edu'}
# {'student_id': 57, 'name': 'Nina57', 'email': 'nina57583@outlook.com'}
# {'student_id': 58, 'name': 'Eva58', 'email': 'eva58778@yahoo.com'}
# {'student_id': 59, 'name': 'Oscar59', 'email': 'oscar59430@outlook.com'}
# {'student_id': 60, 'name': 'Yara60', 'email': 'yara60202@school.edu'}
# {'student_id': 61, 'name': 'Oscar61', 'email': 'oscar61665@school.edu'}
# {'student_id': 62, 'name': 'Rita62', 'email': 'rita62123@outlook.com'}
# {'student_id': 63, 'name': 'Victor63', 'email': 'victor63606@yahoo.com'}
# {'student_id': 64, 'name': 'Xander64', 'email': 'xander64128@school.edu'}
# {'student_id': 65, 'name': 'Hannah65', 'email': 'hannah65506@school.edu'}
# {'student_id': 66, 'name': 'Nina66', 'email': 'nina66787@gmail.com'}
# {'student_id': 67, 'name': 'Victor67', 'email': 'victor67995@outlook.com'}
# {'student_id': 68, 'name': 'Karen68', 'email': 'karen68206@gmail.com'}
# {'student_id': 69, 'name': 'Grace69', 'email': 'grace69854@yahoo.com'}
# {'student_id': 70, 'name': 'Jack70', 'email': 'jack70664@outlook.com'}
# {'student_id': 71, 'name': 'Nina71', 'email': 'nina71140@gmail.com'}
# {'student_id': 72, 'name': 'Ian72', 'email': 'ian72352@outlook.com'}
# {'student_id': 73, 'name': 'Grace73', 'email': 'grace73194@gmail.com'}
# {'student_id': 74, 'name': 'Grace74', 'email': 'grace74943@outlook.com'}
# {'student_id': 75, 'name': 'Quincy75', 'email': 'quincy75112@school.edu'}
# {'student_id': 76, 'name': 'Oscar76', 'email': 'oscar76730@gmail.com'}
# {'student_id': 77, 'name': 'Grace77', 'email': 'grace77178@school.edu'}
# {'student_id': 78, 'name': 'Ian78', 'email': 'ian78228@yahoo.com'}
# {'student_id': 79, 'name': 'Xander79', 'email': 'xander79935@school.edu'}
# {'student_id': 80, 'name': 'Tina80', 'email': 'tina80300@outlook.com'}
# {'student_id': 81, 'name': 'Wendy81', 'email': 'wendy81147@school.edu'}
# {'student_id': 82, 'name': 'Karen82', 'email': 'karen82995@gmail.com'}
# {'student_id': 83, 'name': 'Leo83', 'email': 'leo83394@outlook.com'}
# {'student_id': 84, 'name': 'Bob84', 'email': 'bob84871@yahoo.com'}
# {'student_id': 85, 'name': 'Rita85', 'email': 'rita85757@school.edu'}
# {'student_id': 86, 'name': 'Alice86', 'email': 'alice86674@school.edu'}
# {'student_id': 87, 'name': 'Sam87', 'email': 'sam87600@outlook.com'}
# {'student_id': 88, 'name': 'Wendy88', 'email': 'wendy88626@outlook.com'}
# {'student_id': 89, 'name': 'Tina89', 'email': 'tina89877@yahoo.com'}
# {'student_id': 90, 'name': 'Zane90', 'email': 'zane90905@yahoo.com'}
# {'student_id': 91, 'name': 'Tina91', 'email': 'tina91565@school.edu'}
# {'student_id': 92, 'name': 'Wendy92', 'email': 'wendy92509@gmail.com'}
# {'student_id': 93, 'name': 'Quincy93', 'email': 'quincy93754@gmail.com'}
# {'student_id': 94, 'name': 'Eva94', 'email': 'eva94917@outlook.com'}
# {'student_id': 95, 'name': 'Tina95', 'email': 'tina95115@gmail.com'}
# {'student_id': 96, 'name': 'Ian96', 'email': 'ian96659@gmail.com'}
# {'student_id': 97, 'name': 'Mona97', 'email': 'mona97589@yahoo.com'}
# {'student_id': 98, 'name': 'Leo98', 'email': 'leo98916@gmail.com'}
# {'student_id': 99, 'name': 'Bob99', 'email': 'bob99616@gmail.com'}
# {'student_id': 100, 'name': 'Paul100', 'email': 'paul100458@outlook.com'}

# %% [markdown]
# 13 .Create a program to count how many students are enrolled per course and display results in descending order.

# %%
pipeline = [
    {"$group": {"_id": "$course_name", "num_students": {"$sum": 1}}},
    {"$sort": {"num_students": -1}}
]

# Run aggregation on the collection
results = list(db.enrollment.aggregate(pipeline))

# Print results
for doc in results:
    print(f"Course: {doc['_id']}, Students Enrolled: {doc['num_students']}")

# %% [markdown]
# 14 .Write a Python script that accepts a course name as input and returns all enrolled students with their grades.

# %%
course_name = input("Enter course name (partial allowed): ")

# find matching courses
for course in db.courses.find({"course_name": {"$regex": course_name, "$options": "i"}}):
    print(f"\nStudents enrolled in {course['course_name']}:\n")
    enrollments = db.enrollment.find({"course_id": course["course_id"]})
    found = False
    for e in enrollments:
        student = db.students.find_one({"student_id": e["student_id"]})
        if student:
            found = True
            print("ID:", student["student_id"],
                  "| Name:", student["name"],
                  "| Grade:", student["grade"])
    if not found:
        print("No students enrolled.")

# %% [markdown]
# 15 .Export the contents of the students table into a CSV file using Python.

# %%
students_data = list(db.students.find())

# Convert to DataFrame
df = pd.DataFrame(students_data)

# Optionally remove the MongoDB default '_id' column
if "_id" in df.columns:
    df = df.drop(columns=["_id"])

# Export to CSV
df.to_csv("students.csv", index=False)

print("Students data exported to students.csv successfully!")
# Out:
# Students data exported to students.csv successfully!

# %% [markdown]
# 18 .Handle exceptions in Python to gracefully catch duplicate entries (e.g., inserting a student with the same ID).

# %%
from pymongo import MongoClient, errors

try:
    db.students.insert_one(student)
    print("Student inserted successfully!")
except errors.DuplicateKeyError:
    print(f"Duplicate entry! Student with ID {student['student_id']} already exists.")
# Out:
# Duplicate entry! Student with ID 1 already exists.

# %% [markdown]
# 19 .Write a program to implement transactions in Python: ○ Insert a student ○ Enroll them in a course ○ Roll back if the second query fails

# %%
new_student = {"student_id": 10, "name": "John Doe", "age": 21}
new_enrollment = {"student_id": 10, "course_name": "Math", "grade": "A"}

try:
    # Start a session
    with client.start_session() as session:
        # Start a transaction
        with session.start_transaction():
            # Insert the student
            db.students.insert_one(new_student, session=session)
            
            # Simulate possible failure: uncomment next line to test rollback
            # raise Exception("Simulated failure during enrollment")
            
            # Enroll the student
            db.enrollment.insert_one(new_enrollment, session=session)

    print("Transaction completed successfully!")

except Exception as e:
    print(f"Transaction aborted due to error: {e}")
# Out:
# Transaction aborted due to error: Transaction numbers are only allowed on a replica set member or mongos, full error: {'ok': 0.0, 'errmsg': 'Transaction numbers are only allowed on a replica set member or mongos', 'code': 20, 'codeName': 'IllegalOperation'}

# %% [markdown]
# 20 .Close the database connection safely in Python, ensuring both cursor and connection are properly closed.

# %%
client.close()

print("MongoDB connection closed safely.")
# Out:
# MongoDB connection closed safely.
